# %% [markdown]
# ### Importing the  Modules

# %%
import pandas as pd
from sklearn.datasets import load_iris 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Importing Iris dataset
# #### For the program to run, i make sure to copy both the notebbok and the data into my working folder

# %%
data = pd.read_csv('iris.data')
data.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %% [markdown]
# ### The Summary of my Iris Dataset

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.051007      3.774497     1.205369
# std        0.828594     0.433499      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Summary of each variable
# ##### The write function will create the text file named 'iris_summary_stats.txt' where the summary of each variable will be saved

# %%
sepal_len = data['sepal_length'].describe()
print(sepal_len)

#sepal_len.to_csv('iris_summary_stats.txt', sep='\t')
with open('iris_summary_stats.txt', 'w') as fl:
    fl.write(sepal_len.to_csv(sep='\t')+'\n')
# Out:
# count    149.000000
# mean       5.848322
# std        0.828594
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %%
sepal_wid = data['sepal_width'].describe()
print(sepal_wid)
with open('iris_summary_stats.txt', 'a+') as fl:
    fl.write(sepal_wid.to_csv(sep='\t')+'\n')

# %%
petal_len = data['petal_length'].describe()
print(petal_len)
with open('iris_summary_stats.txt', 'a+') as fl:
    fl.write(petal_len.to_csv(sep='\t')+'\n')

# %%
petal_wid = data['petal_width'].describe()
print(petal_wid)
with open('iris_summary_stats.txt', 'a+') as fl:
    fl.write(petal_wid.to_csv(sep='\t')+'\n')
# Out:
# count    149.000000
# mean       1.205369
# std        0.761292
# min        0.100000
# 25%        0.300000
# 50%        1.300000
# 75%        1.800000
# max        2.500000
# Name: petal_width, dtype: float64

# %% [markdown]
# ### Plotting Historgram for each variable
# #### The 'Savefig' function create a png file for each variable

# %%
sep_len = data['sepal_lenght']
plt.hist(sep_len)
plt.savefig('sep_len.png')

# %%
sep_wid = data['sepal_width']
plt.hist(sep_wid)
plt.savefig('sep_wid.png')

# %%
pet_len = data['petal_len']
plt.hist(pet_len)
plt.savefig('pet_len.png')

# %%
pet_wid = data['petal_width']
plt.hist(pet_wid)
plt.savefig('pet_wid.png')

# %% [markdown]
# ### Grouping and plotting the scatter plot for each pair of species

# %%
setosa_df = data[data['class'] == 'Iris-setosa']
setosa_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
sns.pairplot(setosa_df)

# %%
versicolor_df = data[data['class'] == 'Iris-versicolor']
versicolor_df.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width            class
# 49           7.0          3.2           4.7          1.4  Iris-versicolor
# 50           6.4          3.2           4.5          1.5  Iris-versicolor
# 51           6.9          3.1           4.9          1.5  Iris-versicolor
# 52           5.5          2.3           4.0          1.3  Iris-versicolor
# 53           6.5          2.8           4.6          1.5  Iris-versicolor

# %%
sns.pairplot(versicolor_df)

# %%
virginica_df = data[data['class'] == 'Iris-virginica']
virginica_df.head()

# %%
sns.pairplot(virginica_df)

# %% [markdown]
# ### Other analysis

# %%
sns.pairplot(data, hue='class')

# %%
data.groupby(['class']).agg('count')
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# class
# Iris-setosa                49           49            49           49
# Iris-versicolor            50           50            50           50
# Iris-virginica             50           50            50           50
